# %%
import os

os.environ['http_proxy'] = 'socks5://127.0.0.1:7891'
os.environ['https_proxy'] = 'socks5://127.0.0.1:7891'

os.environ['HF_HOME'] = '/data1/chenyifeng/tmp'
os.environ['HUGGINGFACE_HUB_CACHE'] = '/data1/chenyifeng/tmp'
os.environ['TORCH_HOME'] = '/data1/chenyifeng/tmp'

# 禁用 Xet 存储协议（解决网络令牌请求失败）
os.environ["HF_HUB_DISABLE_XET"] = "1"        # 官方推荐变量
os.environ["HF_XET_DISABLE"] = "1"            # 部分旧版本可能使用这个
# 禁用 hf_transfer（可选，有时会与 Xet 冲突）
os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "0"

from huggingface_hub import snapshot_download

save_dir = "models/BAGEL-7B-MoT"
repo_id = "ByteDance-Seed/BAGEL-7B-MoT"

snapshot_download(
    repo_id=repo_id,
    repo_type="model",
    local_dir=save_dir,          
    local_dir_use_symlinks=False,  
    #allow_patterns=[],     
)
# Out:
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 14 files:   0%|          | 0/14 [00:00<?, ?it/s]
# ...
# '/data1/chenyifeng/LM-skills/SFT/Bagel/models/BAGEL-7B-MoT'

# %%
conda create -n bagel python=3.11 -y
conda activate bagel

pip install -r requirements.txt

wget https://github.com/Dao-AILab/flash-attention/releases/download/v2.7.4.post1/flash_attn-2.7.4.post1+cu12torch2.5cxx11abiFALSE-cp311-cp311-linux_x86_64.whl
pip install ./flash_attn-2.7.4.post1+cu12torch2.5cxx11abiFALSE-cp311-cp311-linux_x86_64.whl
